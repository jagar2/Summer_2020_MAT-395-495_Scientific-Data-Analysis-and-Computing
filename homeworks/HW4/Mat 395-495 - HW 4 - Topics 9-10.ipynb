# %% [markdown]
# **Homework**: Topics 9-10
#
# **Due**: TBD
#
# **Submission**: Submit as Juptyer notebook (ipynb) which runs in Colab (https://colab.research.google.com/) via your shared google drive folder.
#
# **Note**: Datasets are provided via GitHub.

# %% [markdown]
# # Problem 1

# %% [markdown]
# 1) In the course of a couple hours, a material scientist makes 12 measurements on the strength of a nuclear decay signal emanating from your diffusion couple experiment. The values you record in millicuries:
#
# 12, 34, 22, 14, 22, 17, 24, 22, 18, 14, 18, 12
#
# Given the long-life time of the radioactive tracer, the activity of the material does not change over the duration of the measurement, and as such a constant value is anticipated.
#
# 1. What are the mean and standard deviations from this data set?
# 1. According to Chauvenet's criterion, would it be justified to reject the value of 34 as a mistake? Explain your reasoning clearly.
# 1. If the data point is rejected, what are the new values for the mean and standard deviation? Does this significantly change the outcome of the measurement?

# %% [markdown]
# # Problem 2

# %% [markdown]
# Two dice are thrown together 360 times and the total score is recorded for each throw. The possible totals are 2, 3, ... , 12 and their numbers of occurences are as shown in the Table below.
# 1. Calculate the probabilities for each total and hence the expected number of occurrences (assuming the dice are true).
# 1. Calculate χ<sup>2</sup>, d, and χ<sup>2</sup>/d.
# 1. Assuming the dice are true, what is the probability of getting the value χ<sup>2</sup>/d this large or larger? Find and use the appropriate python function to provide this value--this should not be a table lookup.
# 1. At the 5% level of significance, can you reject the hypothesis that the dice are true? At the 1% level?

# %%
import pandas as pd
import numpy as np
data = {'Total Score':np.linspace(2,12,11),
        'Occurrences':[6, 14, 23, 35, 57, 50, 44, 49, 39, 27, 16]}

pd.DataFrame(data)
# Out:
#     Total Score  Occurrences
# 0           2.0            6
# 1           3.0           14
# 2           4.0           23
# 3           5.0           35
# 4           6.0           57
# 5           7.0           50
# 6           8.0           44
# 7           9.0           49
# 8          10.0           39
# 9          11.0           27
# 10         12.0           16

# %% [markdown]
# # Problem 3

# %% [markdown]
# To find the spring constant of a spring, a student loads it with various masses M and measures the corresponding lengths l. Her results are shown in the table below. Because the force is $F = m*g = k*(l-l_0)$, for which l<sub>0</sub> is the unstrechted length of the spring, the data should fit a straight line: $l = l_0 + (g/k)m$.
# 1. Make a least-squares fit to this line for the given data and find the best estaimtes for the unstreacthed length l<sub>0</sub> and the spring constant k. Do the calculations yourself (manually) and then check your answer using python's functions.
# 1. Plot the data and the line you found.
# 1. Calculate the linear correlation coefficient, again manually and using python's built in function.
# 1. Calculate the probability of obtaining this value of the linear correlation coefficient, r, or greater, again manually and using a built-in python function. Make sure you have the correct value using the table provided in lecture.

# %%
import pandas as pd
data = {'Load (grams)':[200, 300, 400, 500, 600, 700, 800, 900],
        'Length (cm)':[5.1, 5.5, 5.9, 6.8, 7.4, 7.5, 8.6, 9.4]}

pd.DataFrame(data)

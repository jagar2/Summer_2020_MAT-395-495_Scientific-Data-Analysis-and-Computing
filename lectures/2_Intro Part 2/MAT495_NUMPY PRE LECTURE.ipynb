# %% [markdown]
# # **Numpy**

# %% [markdown]
# ![alt text](https://www.telematika.org/images/slide/scipy.jpg)

# %% [markdown]
# This is an overview of Numpy
# https://numpy.org/
#
#
#
#
#
#
# *   Core library for scientific and numerical computing in python
# *   High performance
# * Multidimensional arrays
# * Dimensions are called 'axes'
#
#
#
#
# Faster, more convenient, and uses less memory than "list"

# %% [markdown]
# #**Basics**

# %%
# Start here for lecture

# %% [markdown]
# # **Assignment 2**
# import anything that needs to be imported-- even if it is imported elsewhere
#
# Save or transfer your .ipynb to your google drive submission folder
#
# Create a 4x4 identity matrix and print it to the screen
# Create a 4x4 random array using np.random.rand and multiply it by the identity matrix from part 1
# Use concatenate function to make the identity matrix twice the original dimensions
# Make a linear numpy array from 1 to 1000 with increments of 1. Make a logarithmically spaced array from 1 to 1E6 of equal length to the preious linear array. Plot the linear (x) vs logarithmic (y) arrays on linear axes.

# %% [markdown]
# **Assignment**: Topic 10, Fitting
#
# **Due**: 21 hours after slide deck completed during class time
#
# **Submission**: Submit as Juptyer notebook (ipynb) which runs in Colab (https://colab.research.google.com/) via your shared google drive folder.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %% [markdown]
# # Problem 1

# %% [markdown]
# 1) Search the web and find function(s) available to you to fit a function to a set of data. Provide a link to the help file(s). Copy-paste (and modify if necessary) sample code from your help file to plot data points and associated fit for the following four types of data. Make up data if necessary.
# 1. a line
# 1. a polynomial
# 1. an exponential
# 1. a Gaussian

# %% [markdown]
# ## Solutions

# %% [markdown]
# More than likely you will want to use scipy/numpy for this:
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
#
# or for polynomials
#
# https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html

# %% [markdown]
# You can also find many examples on the web, here a few randomly found via googling for 1 min:
#
# https://scipython.com/book/chapter-6-numpy/examples/finding-a-best-fit-straight-line/
#
# https://towardsdatascience.com/basic-curve-fitting-of-scientific-data-with-python-9592244a2509
#
# https://www.geeksforgeeks.org/scipy-curve-fitting/
#
# https://astrofrog.github.io/py4sci/_static/15.%20Fitting%20models%20to%20data.html
#
# https://scipy-cookbook.readthedocs.io/items/FittingData.html
#
# https://scipython.com/book/chapter-6-numpy/examples/fitting-the-beer-lambert-law-with-numpy/
